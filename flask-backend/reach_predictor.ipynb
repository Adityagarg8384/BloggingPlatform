# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('medium_data.csv')

# %%
df.head()
# Out:
#    id                                                url  \
# 0   1  https://towardsdatascience.com/a-beginners-gui...
# 1   2  https://towardsdatascience.com/hands-on-graph-...
# 2   3  https://towardsdatascience.com/how-to-use-ggpl...
# 3   4  https://towardsdatascience.com/databricks-how-...
# 4   5  https://towardsdatascience.com/a-step-by-step-...
#
#                                                title  \
# 0  A Beginner’s Guide to Word Embedding with Gens...
# 1  Hands-on Graph Neural Networks with PyTorch & ...
# 2                       How to Use ggplot2 in Python
# 3  Databricks: How to Save Files in CSV on Your L...
# 4  A Step-by-Step Implementation of Gradient Desc...
#
#                                   subtitle   image  claps responses  \
# 0                                      NaN   1.png    850         8
# 1                                      NaN   2.png   1100        11
# 2         A Grammar of Graphics for Python   3.png    767         1
# ...

# %%
df = df.drop(columns = ['url', 'id', 'responses', 'reading_time', 'publication', 'date'])

# %%
df.head()
# Out:
#                                                title  \
# 0  A Beginner’s Guide to Word Embedding with Gens...
# 1  Hands-on Graph Neural Networks with PyTorch & ...
# 2                       How to Use ggplot2 in Python
# 3  Databricks: How to Save Files in CSV on Your L...
# 4  A Step-by-Step Implementation of Gradient Desc...
#
#                                   subtitle   image  claps
# 0                                      NaN   1.png    850
# 1                                      NaN   2.png   1100
# 2         A Grammar of Graphics for Python   3.png    767
# 3  When I work on Python projects dealing…  4.jpeg    354
# 4          One example of building neural…  5.jpeg    211

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6508 entries, 0 to 6507
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     6508 non-null   object
#  1   subtitle  3479 non-null   object
#  2   image     6361 non-null   object
#  3   claps     6508 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 203.5+ KB

# %%
df['claps'].max()
# Out:
# 38000

# %%
df.describe()
# Out:
#               claps
# count   6508.000000
# mean     311.076060
# std      950.789896
# min        0.000000
# 25%       54.000000
# 50%      115.000000
# 75%      268.250000
# max    38000.000000

# %%
df.isnull()
# Out:
#       title  subtitle  image  claps
# 0     False      True  False  False
# 1     False      True  False  False
# 2     False     False  False  False
# 3     False     False  False  False
# 4     False     False  False  False
# ...     ...       ...    ...    ...
# 6503  False     False  False  False
# 6504  False     False  False  False
# 6505  False     False  False  False
# 6506  False     False  False  False
# 6507  False     False  False  False
#
# [6508 rows x 4 columns]

# %%
dummy = pd.get_dummies(df['subtitle'])

# %%
dummy.head()
# Out:
#    #1 is to write like you speak.  \
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                           False
#
#    #3 — Remain focused on offering value to the…  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    #aws #appsync #amplify #swift…  & How much he/she does NOT need to know.  \
# 0                           False                                     False
# 1                           False                                     False
# 2                           False                                     False
# 3                           False                                     False
# ...

# %%
df = pd.concat([df, dummy], axis = 1)

# %%
df.head()
# Out:
#                                                title  \
# 0  A Beginner’s Guide to Word Embedding with Gens...
# 1  Hands-on Graph Neural Networks with PyTorch & ...
# 2                       How to Use ggplot2 in Python
# 3  Databricks: How to Save Files in CSV on Your L...
# 4  A Step-by-Step Implementation of Gradient Desc...
#
#                                   subtitle   image  claps  \
# 0                                      NaN   1.png    850
# 1                                      NaN   2.png   1100
# 2         A Grammar of Graphics for Python   3.png    767
# 3  When I work on Python projects dealing…  4.jpeg    354
# 4          One example of building neural…  5.jpeg    211
#
#    #1 is to write like you speak.  \
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                           False
#
#    #3 — Remain focused on offering value to the…  \
# ...

# %%
df.drop("subtitle",axis=1,inplace=True)

# %%
dummy = pd.get_dummies(df['title'])
dummy.head()
# Out:
#    #CopyPasteCris and the fight to stop writing from devolving into content marketing  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    #Fail: Artificial Intelligence is a Science  #NoProcesses — Introduction  \
# 0                                        False                        False
# 1                                        False                        False
# 2                                        False                        False
# 3                                        False                        False
# 4                                        False                        False
#
#    (Book Review) The Big Nine: How The Tech Titans & Their Thinking Machines Could Warp Humanity  \
# 0                                              False
# ...

# %%
df = pd.concat([df, dummy], axis = 1)

# %%
df.drop('title', axis = 1, inplace = True)

# %%
dummy = pd.get_dummies(df['image'])
df=pd.concat([df,dummy], axis=1)
df.drop("image",axis=1,inplace=True)

# %%
df = df.map(lambda x: int(x) if isinstance(x, bool) else x)

# %%
x = df.drop(columns = ['claps'])
y = df['claps']

# %%
from sklearn.model_selection import train_test_split


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=1)


print("number of test samples :", x_test.shape[0])
print("number of training samples:",x_train.shape[0])
# Out:
# number of test samples : 1627
# number of training samples: 4881

# %%
from sklearn.linear_model import LinearRegression
lmr = LinearRegression()
lmr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lmr.predict(x_test.iloc[[0]])
# Out:
# array([302.54566482])

# %%
x_test
# Out:
#       #1 is to write like you speak.  \
# 4599                               0
# 2950                               0
# 712                                0
# 6478                               0
# 2927                               0
# ...                              ...
# 5880                               0
# 3676                               0
# 2028                               0
# 4524                               0
# 1236                               0
#
#       #3 — Remain focused on offering value to the…  \
# 4599                                              0
# 2950                                              0
# 712                                               0
# 6478                                              0
# 2927                                              0
# ...                                             ...
# 5880                                              0
# 3676                                              0
# ...
